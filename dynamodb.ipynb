# %% [markdown]
# ### Testing DynamoDB Functions

# %%
CREATE TABLE guestlist (
    id INTEGER PRIMARY KEY,
    title TEXT,
    name TEXT NOT NULL,
    category TEXT,
    party_size INTEGER NOT NULL DEFAULT 1,
    over_21 INTEGER NOT NULL DEFAULT 0,
    responded_rsvp TEXT DEFAULT "No",
    email TEXT,
    phone_number TEXT,
    events_invited TEXT,
    Shreya_Haldi TEXT DEFAULT '',
    Shreya_Haldi_Number INTEGER DEFAULT 0,
    Aman_Haldi TEXT DEFAULT '',
    Aman_Haldi_Number INTEGER DEFAULT 0,
    Sangeet TEXT DEFAULT '",
    Sangeet_Number INTEGER DEFAULT 0,
    Wedding TEXT DEFAULT "",
    Wedding_Number INTEGER DEFAULT 0,
    Reception TEXT DEFAULT "",
    Reception_Number INTEGER DEFAULT 0,
    guest_names TEXT DEFAULT ""
);

# %%
import boto3

dynamo = boto3.client(service_name = 'dynamodb', region_name = "us-east-2")

# %%
dynamo.list_tables()
# Out:
# DEBUG: Event before-parameter-build.dynamodb.ListTables: calling handler <function generate_idempotent_uuid at 0x110ba9bd0>
# DEBUG: Event before-parameter-build.dynamodb.ListTables: calling handler <function block_endpoint_discovery_required_operations at 0x110b649d0>
# DEBUG: Calling endpoint provider with parameters: {'Region': 'us-east-2', 'UseDualStack': False, 'UseFIPS': False}
# DEBUG: Endpoint provider result: https://dynamodb.us-east-2.amazonaws.com
# DEBUG: Event before-call.dynamodb.ListTables: calling handler <function add_recursion_detection_header at 0x110ba9870>
# DEBUG: Event before-call.dynamodb.ListTables: calling handler <function inject_api_version_header_if_needed at 0x110bab400>
# ...

# %%
# Schema for guestlist table

from cs50 import SQL
db = SQL("sqlite:///wedding.db")
name = 'Test Last'
# res = db.execute("SELECT id FROM guestlist WHERE guest_names like '%Test Last%'")
# res = db.execute("SELECT id FROM guestlist WHERE guest_names LIKE ?", f"%{name}%")
res = db.execute("SELECT id FROM guestlist WHERE name= :name OR guest_names LIKE :search_text", name=name, search_text=f"%{name}%")
print(res)
# Out:
# [{'id': 3}, {'id': 4}, {'id': 5}]

# %%
items = {}
data = res[0]
def gettype(x):
    if type(x) is str:
        return 'S'
    elif type(x) is int:
        return 'N'
# Reformat results from res
for key in data.keys():
    # print(key)
    items[key] = {gettype(data[key]): str(data[key])}

# dynamo.put_item(
#     TableName='guestlist', 
#     Item={
#         'id': {
#             'N': '1'
#         },
#         'string': {
#             'S': "valueofstring"
#         }
#     }
# )
# Out:
# DEBUG: Calling dynamodb:put_item with {'TableName': 'guestlist', 'Item': {'id': {'N': '2'}, 'name': {'S': 'valueofstring'}}}
# DEBUG: Event provide-client-params.dynamodb.PutItem: calling handler <function copy_dynamodb_params at 0x116c29ea0>
# DEBUG: Event before-parameter-build.dynamodb.PutItem: calling handler <bound method TransformationInjector.inject_condition_expressions of <boto3.dynamodb.transform.TransformationInjector object at 0x11718f010>>
# DEBUG: Event before-parameter-build.dynamodb.PutItem: calling handler <bound method TransformationInjector.inject_attribute_value_input of <boto3.dynamodb.transform.TransformationInjector object at 0x11718f010>>
# DEBUG: Event before-parameter-build.dynamodb.PutItem: calling handler <function generate_idempotent_uuid at 0x110ba9bd0>
# DEBUG: Event before-parameter-build.dynamodb.PutItem: calling handler <function block_endpoint_discovery_required_operations at 0x110b649d0>
# ...

# %%
print(items)
# Out:
# {'id': {'N': '1'}, 'title': {'S': 'Mr.'}, 'name': {'S': 'Test Test'}, 'category': {'S': 'Groom'}, 'party_size': {'N': '3'}, 'over_21': {'N': '2'}, 'rsvp': {'N': '0'}, 'responded_rsvp': {'S': 'Yes'}, 'email': {'S': 'vyas95.aman@gmail.com'}, 'phone_number': {'S': '2342342345'}, 'events_invited': {'S': 'Aman_Haldi Sangeet Wedding Reception'}, 'Shreya_Haldi': {'S': ''}, 'Aman_Haldi': {'S': 'Test Test, Chotu'}, 'Sangeet': {'S': ''}, 'Wedding': {'S': 'Test Test, Badu, Chotu'}, 'Reception': {'S': 'Test Test, Badu, Chotu'}, 'guest_names': {'S': 'Badu, Chotu'}}

# %%
dynamo.put_item(
    TableName='guestlist', 
    Item=items
)
# Out:
# DEBUG: Event before-parameter-build.dynamodb.PutItem: calling handler <function generate_idempotent_uuid at 0x110ba9bd0>
# DEBUG: Event before-parameter-build.dynamodb.PutItem: calling handler <function block_endpoint_discovery_required_operations at 0x110b649d0>
# DEBUG: Calling endpoint provider with parameters: {'Region': 'us-east-2', 'UseDualStack': False, 'UseFIPS': False}
# DEBUG: Endpoint provider result: https://dynamodb.us-east-2.amazonaws.com
# DEBUG: Event before-call.dynamodb.PutItem: calling handler <function add_recursion_detection_header at 0x110ba9870>
# DEBUG: Event before-call.dynamodb.PutItem: calling handler <function inject_api_version_header_if_needed at 0x110bab400>
# ...

# %%
# Add all current data to DynamoDB

res = db.execute("Select * from guestlist")
items = {}

def gettype(x):
    if type(x) is str:
        return 'S'
    elif type(x) is int:
        return 'N'
for data in res:
    for key in data.keys():
        items[key] = {gettype(data[key]): str(data[key])}
        dynamo.put_item(TableName='guestlist', Item = items)
# Out:
# DEBUG: Event before-parameter-build.dynamodb.PutItem: calling handler <function generate_idempotent_uuid at 0x110ba9bd0>
# DEBUG: Event before-parameter-build.dynamodb.PutItem: calling handler <function block_endpoint_discovery_required_operations at 0x110b649d0>
# DEBUG: Calling endpoint provider with parameters: {'Region': 'us-east-2', 'UseDualStack': False, 'UseFIPS': False}
# DEBUG: Endpoint provider result: https://dynamodb.us-east-2.amazonaws.com
# DEBUG: Event before-call.dynamodb.PutItem: calling handler <function add_recursion_detection_header at 0x110ba9870>
# DEBUG: Event before-call.dynamodb.PutItem: calling handler <function inject_api_version_header_if_needed at 0x110bab400>
# ...

# %%
# Return data from dynamo

from boto3.dynamodb.conditions import Key
dynamo = boto3.resource('dynamodb', region_name='us-east-2')
dynamo = dynamo.Table("guestlist")
resp = dynamo.scan(FilterExpression=Key('name').eq("Aman Vyas")
)

print(resp)
# Out:
# {'Items': [{'Reception': 'Aman Vyas, Moma, Dad, Tinu, Guest', 'Wedding_Number': Decimal('5'), 'party_size': '5', 'Reception_Number': Decimal('5'), 'Sangeet': 'Aman Vyas, Moma, Dad, Tinu, Guest', 'Shreya_Haldi': '', 'Aman_Haldi_Number': Decimal('3'), 'responded_rsvp': 'Yes', 'email': 'VYAS95.AMAN@GMAIL.COM', 'name': 'Aman Vyas', 'Sangeet_Number': Decimal('5'), 'Shreya_Haldi_Number': Decimal('0'), 'events_invited': 'Aman_Haldi Sangeet Wedding Reception', 'category': 'Groom', 'phone_number': '2672222733', 'guest_names': 'Moma, Dad, Tinu, Guest123', 'Wedding': 'Aman Vyas, Moma, Dad, Tinu, Guest', 'id': Decimal('1'), 'over_21': '0', 'Aman_Haldi': 'Aman Vyas, Moma, Dad', 'title': 'Mr.'}], 'Count': 1, 'ScannedCount': 3, 'ResponseMetadata': {'RequestId': 'TBK5KC9JFAHL327A63L66E6L7JVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Wed, 31 Jan 2024 00:09:26 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '748', 'connection': 
# ...

# %%
{'Reception': 'Aman Vyas, Moma, Dad, Tinu, Guest', 
 'Wedding_Number': Decimal('5'), 'party_size': Decimal('5'), 'Reception_Number': Decimal('5'), 'Sangeet': 'Aman Vyas, Moma, Dad, Tinu, Guest', 
 'Shreya_Haldi': '', 
 'Aman_Haldi_Number': Decimal('3'), 'responded_rsvp': 'Yes', 
 'email': 'VYAS95.AMAN@GMAIL.COM', 'name': 'Aman Vyas', 
 'Sangeet_Number': Decimal('5'), 'Shreya_Haldi_Number': Decimal('0'), 'events_invited': 'Aman_Haldi Sangeet Wedding Reception', 
 'category': 'Groom', 
 'phone_number': '2672222733', 'guest_names': 'Moma, Dad, Tinu, Guest', 'Wedding': 'Aman Vyas, Moma, Dad, Tinu, Guest', 
 'id': Decimal('1'), 
 'over_21': Decimal('0'), 
 'Aman_Haldi': 'Aman Vyas, Moma, Dad', 'title': 'Mr.'}

# %%
# item = {
#   "id": {
#     "N": "2"
#   },
#   "Aman_Haldi": {
#     "S": "Aman Vyas, Moma, Dad"
#   },
#   "Aman_Haldi_Number": {
#     "N": "3"
#   },
#   "category": {
#     "S": "Groom"
#   },
#   "email": {
#     "S": "VYAS95.AMAN@GMAIL.COM"
#   },
#   "events_invited": {
#     "S": "Aman_Haldi Sangeet Wedding Reception"
#   },
#   "guest_names": {
#     "S": "Moma, Dad, Tinu, Guest"
#   },
#   "name": {
#     "S": "Aman Vyas"
#   },
#   "over_21": {
#     "N": "0"
#   },
#   "party_size": {
#     "N": "5"
#   },
#   "phone_number": {
#     "S": "2672222733"
#   },
#   "Reception": {
#     "S": "Aman Vyas, Moma, Dad, Tinu, Guest"
#   },
#   "Reception_Number": {
#     "N": "5"
#   },
#   "responded_rsvp": {
#     "S": "Yes"
#   },
#   "Sangeet": {
#     "S": "Aman Vyas, Moma, Dad, Tinu, Guest"
#   },
#   "Sangeet_Number": {
#     "N": "5"
#   },
#   "Shreya_Haldi": {
#     "S": ""
#   },
#   "Shreya_Haldi_Number": {
#     "N": "0"
#   },
#   "title": {
#     "S": "Mr."
#   },
#   "Wedding": {
#     "S": "Aman Vyas, Moma, Dad, Tinu, Guest"
#   },
#   "Wedding_Number": {
#     "N": "5"
#   }
# }

item = {'Reception': 'Aman Vyas, Moma, Dad, Tinu, Guest', 
 'Wedding_Number': 5, 'party_size': 5, 'Reception_Number': 5, 'Sangeet': 'Aman Vyas, Moma, Dad, Tinu, Guest', 
 'Shreya_Haldi': '', 
 'Aman_Haldi_Number': 3, 'responded_rsvp': 'Yes', 
 'email': 'VYAS95.AMAN@GMAIL.COM', 'name': 'Aman Vyas', 
 'Sangeet_Number': 5, 'Shreya_Haldi_Number': 0, 'events_invited': 'Aman_Haldi Sangeet Wedding Reception', 
 'category': 'Groom', 
 'phone_number': '2672222733', 'guest_names': 'Moma, Dad, Tinu, Guest', 'Wedding': 'Aman Vyas, Moma, Dad, Tinu, Guest', 
 'id': 2, 
 'over_21': 0, 
 'Aman_Haldi': 'Aman Vyas, Moma, Dad', 'title': 'Mr.'}

dynamo.put_item(Item=item)
# Out:
# DEBUG: Calling dynamodb:put_item with {'TableName': 'guestlist', 'Item': {'Reception': 'Aman Vyas, Moma, Dad, Tinu, Guest', 'Wedding_Number': 5, 'party_size': 5, 'Reception_Number': 5, 'Sangeet': 'Aman Vyas, Moma, Dad, Tinu, Guest', 'Shreya_Haldi': '', 'Aman_Haldi_Number': 3, 'responded_rsvp': 'Yes', 'email': 'VYAS95.AMAN@GMAIL.COM', 'name': 'Aman Vyas', 'Sangeet_Number': 5, 'Shreya_Haldi_Number': 0, 'events_invited': 'Aman_Haldi Sangeet Wedding Reception', 'category': 'Groom', 'phone_number': '2672222733', 'guest_names': 'Moma, Dad, Tinu, Guest', 'Wedding': 'Aman Vyas, Moma, Dad, Tinu, Guest', 'id': 2, 'over_21': 0, 'Aman_Haldi': 'Aman Vyas, Moma, Dad', 'title': 'Mr.'}}
# DEBUG: Event provide-client-params.dynamodb.PutItem: calling handler <function copy_dynamodb_params at 0x116c29ea0>
# ...

# %%
dynamo.delete_item(Key={"id": 3})
# Out:
# DEBUG: Calling dynamodb:delete_item with {'TableName': 'guestlist', 'Key': {'id': 3}}
# DEBUG: Event provide-client-params.dynamodb.DeleteItem: calling handler <function copy_dynamodb_params at 0x116c29ea0>
# DEBUG: Event before-parameter-build.dynamodb.DeleteItem: calling handler <bound method TransformationInjector.inject_condition_expressions of <boto3.dynamodb.transform.TransformationInjector object at 0x1175ace80>>
# DEBUG: Event before-parameter-build.dynamodb.DeleteItem: calling handler <bound method TransformationInjector.inject_attribute_value_input of <boto3.dynamodb.transform.TransformationInjector object at 0x1175ace80>>
# DEBUG: Event before-parameter-build.dynamodb.DeleteItem: calling handler <function generate_idempotent_uuid at 0x110ba9bd0>
# DEBUG: Event before-parameter-build.dynamodb.DeleteItem: calling handler <function block_endpoint_discovery_required_operations at 0x110b649d0>
# ...

# %%
dynamo.scan()['Count']
# Out:
# DEBUG: Calling dynamodb:scan with {'TableName': 'guestlist'}
# DEBUG: Event provide-client-params.dynamodb.Scan: calling handler <function copy_dynamodb_params at 0x116c29ea0>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <bound method TransformationInjector.inject_condition_expressions of <boto3.dynamodb.transform.TransformationInjector object at 0x1175ace80>>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <bound method TransformationInjector.inject_attribute_value_input of <boto3.dynamodb.transform.TransformationInjector object at 0x1175ace80>>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <function generate_idempotent_uuid at 0x110ba9bd0>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <function block_endpoint_discovery_required_operations at 0x110b649d0>
# DEBUG: Calling endpoint provider with parameters: {'Region': 'us-east-2', 'UseDualStack': False, 'UseFIPS': False}
# ...

# %%
dyn = [{'Reception': 'Aman Vyas, Moma, Dad, Tinu, Guest', 'Wedding_Number': 5, 'party_size': 5, 'Reception_Number': 5, 'Sangeet': 'Aman Vyas, Moma, Dad, Tinu, Guest', 'Shreya_Haldi': '', 'Aman_Haldi_Number': 3, 'responded_rsvp': 'Yes', 'email': 'VYAS95.AMAN@GMAIL.COM', 'Sangeet_Number': 5, 'name': 'Aman Vyas', 'Shreya_Haldi_Number': 0, 'events_invited': 'Aman_Haldi Sangeet Wedding Reception', 'guest_names': 'Moma, Dad, Tinu, Guest', 'phone_number': '2672222733', 'category': 'Groom', 'Wedding': 'Aman Vyas, Moma, Dad, Tinu, Guest', 'id': 2, 'over_21': 0, 'Aman_Haldi': 'Aman Vyas, Moma, Dad', 'title': 'Mr.'}, {'Reception': 'Aman Vyas, Moma, Dad, Tinu, Guest', 'Wedding_Number': 5, 'party_size': 5, 'Reception_Number': 5, 'Sangeet': 'Aman Vyas, Moma, Dad, Tinu, Guest', 'Shreya_Haldi': '', 'Aman_Haldi_Number': 3, 'responded_rsvp': 'Yes', 'email': 'VYAS95.AMAN@GMAIL.COM', 'name': 'Aman Vyas', 'Sangeet_Number': 5, 'Shreya_Haldi_Number': 0, 'events_invited': 'Aman_Haldi Sangeet Wedding Reception', 'category': 'Groom', 'phone_number': '2672222733', 'guest_names': 'Moma, Dad, Tinu, Guest', 'Wedding': 'Aman Vyas, Moma, Dad, Tinu, Guest', 'id': 1, 'over_21': 0, 'Aman_Haldi': 'Aman Vyas, Moma, Dad', 'title': 'Mr.'}]

sql = [{'id': 1, 'title': 'Mr.', 'name': 'Aman Vyas', 'category': 'Groom', 'party_size': 5, 'over_21': 0, 'responded_rsvp': 'Yes', 'email': 'VYAS95.AMAN@GMAIL.COM', 'phone_number': '2672222733', 'events_invited': 'Aman_Haldi Sangeet Wedding Reception', 'Shreya_Haldi': '', 'Shreya_Haldi_Number': 0, 'Aman_Haldi': 'Aman Vyas, Moma, Dad', 'Aman_Haldi_Number': 3, 'Sangeet': 'Aman Vyas, Moma, Dad, Tinu, Guest', 'Sangeet_Number': 5, 'Wedding': 'Aman Vyas, Moma, Dad, Tinu, Guest', 'Wedding_Number': 5, 'Reception': 'Aman Vyas, Moma, Dad, Tinu, Guest', 'Reception_Number': 5, 'guest_names': 'Moma, Dad, Tinu, Guest'}, {'id': 2, 'title': 'Ms.', 'name': 'Shreya Patel', 'category': 'Bride', 'party_size': 5, 'over_21': 0, 'responded_rsvp': 'Yes', 'email': 'VYAS95.AMAN@GMAIL.COM', 'phone_number': '2672222733', 'events_invited': 'Shreya_Haldi Sangeet Wedding Reception', 'Shreya_Haldi': 'Shreya Patel, Momma Bear', 'Shreya_Haldi_Number': 2, 'Aman_Haldi': '', 'Aman_Haldi_Number': 0, 'Sangeet': 'Shreya Patel, Momma Bear', 'Sangeet_Number': 2, 'Wedding': 'Shreya Patel, Momma Bear', 'Wedding_Number': 2, 'Reception': 'Shreya Patel, Momma Bear', 'Reception_Number': 2, 'guest_names': 'Momma Bear, Papa, Pavan'}]

# %%
dyn = dyn[0]
sql = sql[0]

for x in dyn:
    print(f"SQL: {sql[x]}      DYN: {dyn[x]}")
    dyn[x] = 'same'
    sql[x] = 'same'

print("FINAL DYN:", dyn)
print("FINAL SQL:", sql)
# Out:
# SQL: Aman Vyas, Moma, Dad, Tinu, Guest      DYN: Aman Vyas, Moma, Dad, Tinu, Guest
# SQL: 5      DYN: 5
# SQL: 5      DYN: 5
# SQL: 5      DYN: 5
# SQL: Aman Vyas, Moma, Dad, Tinu, Guest      DYN: Aman Vyas, Moma, Dad, Tinu, Guest
# SQL:       DYN:
# SQL: 3      DYN: 3
# SQL: Yes      DYN: Yes
# SQL: VYAS95.AMAN@GMAIL.COM      DYN: VYAS95.AMAN@GMAIL.COM
# SQL: 5      DYN: 5
# SQL: Aman Vyas      DYN: Aman Vyas
# SQL: 0      DYN: 0
# SQL: Aman_Haldi Sangeet Wedding Reception      DYN: Aman_Haldi Sangeet Wedding Reception
# SQL: Moma, Dad, Tinu, Guest      DYN: Moma, Dad, Tinu, Guest
# SQL: 2672222733      DYN: 2672222733
# SQL: Groom      DYN: Groom
# SQL: Aman Vyas, Moma, Dad, Tinu, Guest      DYN: Aman Vyas, Moma, Dad, Tinu, Guest
# SQL: 1      DYN: 2
# SQL: 0      DYN: 0
# SQL: Aman Vyas, Moma, Dad      DYN: Aman Vyas, Moma, Dad
# SQL: Mr.      DYN: Mr.
# ...

# %%
from boto3.dynamodb.conditions import Attr
# dynamo.scan(FilterExpression=Attr('name').eq("Test Last") or Attr('guest_names').contains('Test Last'))['Items']
result1 = []
result2 = []

try:
    result1 = dynamo.scan(FilterExpression=Key('name').eq('Test Last'))['Items']
except: 
    print("executed")
    result2 = dynamo.scan(FilterExpression=Key('guest_names').contains('Test Last'))['Items']

print(result1)
print(result2)
# Out:
# []
# []

# %%
db.execute("SELECT Wedding from guestlist WHERE Wedding is not ''")
# Out:
# [{'Wedding': 'Aman Vyas, Moma, Dad, Tinu, Guest'},
#  {'Wedding': 'Shreya Patel, Momma Bear'}]

# %%
dynamo.update_item(Key={"id": 2}, AttributeUpdates={'Wedding': {"Value": "Shreya Patel, Pavan"}})
# Out:
# DEBUG: Calling dynamodb:update_item with {'TableName': 'guestlist', 'Key': {'id': 2}, 'AttributeUpdates': {'Wedding': {'Value': 'Shreya Patel, Pavan'}}}
# DEBUG: Event provide-client-params.dynamodb.UpdateItem: calling handler <function copy_dynamodb_params at 0x116c29ea0>
# DEBUG: Event before-parameter-build.dynamodb.UpdateItem: calling handler <bound method TransformationInjector.inject_condition_expressions of <boto3.dynamodb.transform.TransformationInjector object at 0x1175ace80>>
# DEBUG: Event before-parameter-build.dynamodb.UpdateItem: calling handler <bound method TransformationInjector.inject_attribute_value_input of <boto3.dynamodb.transform.TransformationInjector object at 0x1175ace80>>
# DEBUG: Event before-parameter-build.dynamodb.UpdateItem: calling handler <function generate_idempotent_uuid at 0x110ba9bd0>
# DEBUG: Event before-parameter-build.dynamodb.UpdateItem: calling handler <function block_endpoint_discovery_required_operations at 0x110b649d0>
# ...

# %%
person = dynamo.scan(FilterExpression=Key('id').eq(2))['Items'][0]

person['guest_names'] = 'Momma Bear'
person['over_21'] = 2

dynamo.put_item(Item=person)
# Out:
# DEBUG: Calling dynamodb:scan with {'TableName': 'guestlist', 'FilterExpression': <boto3.dynamodb.conditions.Equals object at 0x1177b1840>}
# DEBUG: Event provide-client-params.dynamodb.Scan: calling handler <function copy_dynamodb_params at 0x116c29ea0>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <bound method TransformationInjector.inject_condition_expressions of <boto3.dynamodb.transform.TransformationInjector object at 0x1175ace80>>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <bound method TransformationInjector.inject_attribute_value_input of <boto3.dynamodb.transform.TransformationInjector object at 0x1175ace80>>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <function generate_idempotent_uuid at 0x110ba9bd0>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <function block_endpoint_discovery_required_operations at 0x110b649d0>
# ...

# %%
db.execute("SELECT title FROM guestlist WHERE id = ?", 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/amanvyas/Desktop/Coding/Projects/Wedding_Website/dynamodb.ipynb Cell 21 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/amanvyas/Desktop/Coding/Projects/Wedding_Website/dynamodb.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> db.execute("SELECT title FROM guestlist WHERE id = ?", 1)
#
# NameError: name 'db' is not defined

# %%
test = dynamo.scan(FilterExpression=Key('id').eq(3))['Items'][0]
# for x in test:
#     if type(test[x]) is not int and type(test[x]) is not str:
#         test[x] = int(test[x])
#     print(x, type(test[x]), test[x])
        
print(test)
# Out:
# DEBUG: Calling dynamodb:scan with {'TableName': 'guestlist', 'FilterExpression': <boto3.dynamodb.conditions.Equals object at 0x117145090>}
# DEBUG: Event provide-client-params.dynamodb.Scan: calling handler <function copy_dynamodb_params at 0x116c29ea0>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <bound method TransformationInjector.inject_condition_expressions of <boto3.dynamodb.transform.TransformationInjector object at 0x1175ace80>>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <bound method TransformationInjector.inject_attribute_value_input of <boto3.dynamodb.transform.TransformationInjector object at 0x1175ace80>>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <function generate_idempotent_uuid at 0x110ba9bd0>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <function block_endpoint_discovery_required_operations at 0x110b649d0>
# ...

# %%
test = dynamo.scan(FilterExpression=Key('id').eq(3))['Items'][0]
if 'name' in test.keys():
    print(True)
else:
    print(False)
# Out:
# DEBUG: Calling dynamodb:scan with {'TableName': 'guestlist', 'FilterExpression': <boto3.dynamodb.conditions.Equals object at 0x1173dbcd0>}
# DEBUG: Event provide-client-params.dynamodb.Scan: calling handler <function copy_dynamodb_params at 0x116c29ea0>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <bound method TransformationInjector.inject_condition_expressions of <boto3.dynamodb.transform.TransformationInjector object at 0x1175ace80>>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <bound method TransformationInjector.inject_attribute_value_input of <boto3.dynamodb.transform.TransformationInjector object at 0x1175ace80>>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <function generate_idempotent_uuid at 0x110ba9bd0>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <function block_endpoint_discovery_required_operations at 0x110b649d0>
# ...

# %%
def __convert_decimal_format(person):
    for field in person:
        if type(person[field]) is not int and type(person[field]) is not str:
            person[field] = int(person[field])
    return person

person = dynamo.scan(FilterExpression=Key('id').eq(3))['Items'][0]
print("Person resp: ", person)
person = __convert_decimal_format(person)
print("Person converted: ", person)
if 'guest_names' in person.keys():
    guests = person['guest_names'].split(", ")
else: 
    guests = ""
guest_num = len(guests)

print("Guests: ", guests)
print("Guest Num: ", guest_num)
# Out:
# DEBUG: Calling dynamodb:scan with {'TableName': 'guestlist', 'FilterExpression': <boto3.dynamodb.conditions.Equals object at 0x11718f6a0>}
# DEBUG: Event provide-client-params.dynamodb.Scan: calling handler <function copy_dynamodb_params at 0x116c29ea0>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <bound method TransformationInjector.inject_condition_expressions of <boto3.dynamodb.transform.TransformationInjector object at 0x1175ace80>>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <bound method TransformationInjector.inject_attribute_value_input of <boto3.dynamodb.transform.TransformationInjector object at 0x1175ace80>>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <function generate_idempotent_uuid at 0x110ba9bd0>
# DEBUG: Event before-parameter-build.dynamodb.Scan: calling handler <function block_endpoint_discovery_required_operations at 0x110b649d0>
# ...

# %%
for x in range(2, 5):
    print(x)
# Out:
# 2
# 3
# 4

# %%
guests = ['a', 'b']
if 1 > 2 and guests[3]:
    print(True)
else:
    print(False)

# print(len(guests))
# Out:
# False

# %%
res = dynamo.scan(FilterExpression=Key('name').eq('Test Test'))['Items']

# len(res)
if len(res) > 1:
    for x in res:
        guest = x['guest_names'].split(',')[0]
        print(guest)
else:
    res
# Out:
# Test Kumar
# Test Duplicate
